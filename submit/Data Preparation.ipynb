# %%
import pandas as pd

# %%
case = pd.read_pickle('../iecoe-sg-technical-interview/data/df_cases_200906.gzip')
case = case.sort_values('CaseId')
case.head()
# Out:
#             CaseId                                           FileName  \
# 1161  003061189006  003061189006_69176036_Order form_978-1-62414-9...
# 1102  003061189067  003061189067_26173467_Order form_978-1-904782-...
# 1092  003061189156  003061189156_47966765_Contract Documents_978-0...
# 1157  003061189229  003061189229_69115288_Master contract_978-0-11...
# 1158  003061189229  003061189229_21094545_other documents_978-1-81...
#
#      Language StartDate        DocumentType IsExecuted  \
# 1161       EN  20190708          Order form       True
# 1102       EN  20190530          Order form       True
# 1092       EN  20190731  Contract Documents       True
# 1157       EN  20190801     Master contract      False
# 1158       EN  20190801     other documents       True
#
#                                                OcrText  QualityScore
# 1161            As difficult behavior her myself help.      0.855230
# 1102                           Present can phone form.      0.849095
# 1092  Section science difference success wish it wide.      0.894667
# 1157                         Down maintain Republican.      0.616230
# 1158                    Accept sell leader herself if.      0.905182

# %%
label = pd.read_pickle('../iecoe-sg-technical-interview/data/df_label_200906.gzip')
label = label.sort_values('CaseId')
label.head()
# Out:
#            CaseId label_1 label_2
# 601  003061189006    True   False
# 564  003061189067    True   False
# 558  003061189156   False   False
# 599  003061189229   False   False
# 557  003061189242   False   False

# %%
case = case.drop(columns=['Language', 'StartDate', 'DocumentType'])

# %%
cases_list = case.values.tolist() 
cases_size = len(cases_list)

# %%
clean_list = []

# %%
for i in range(0, cases_size): 
    if(cases_list[i][2] == False or cases_list[i][4] < 0.81): 
        cases_list[i][1] = "[" + str(cases_list[i][1]) + "]"
        clean_list.append([cases_list[i][0], cases_list[i][1], "", ""])
    else:
        cases_list[i][1] = "[" + str(cases_list[i][1]) + "]"
        clean_list.append([cases_list[i][0], "", cases_list[i][1], cases_list[i][3]])

# %%
clean_df = pd.DataFrame(clean_list, columns=['CaseId', 'InvalidFileNames', 'ValidFileNames', 'OcrText'])

# %%
clean_df.head()
# Out:
#          CaseId                                   InvalidFileNames  \
# 0  003061189006
# 1  003061189067
# 2  003061189156
# 3  003061189229  [003061189229_69115288_Master contract_978-0-1...
# 4  003061189229
#
#                                       ValidFileNames  \
# 0  [003061189006_69176036_Order form_978-1-62414-...
# 1  [003061189067_26173467_Order form_978-1-904782...
# 2  [003061189156_47966765_Contract Documents_978-...
# 3
# 4  [003061189229_21094545_other documents_978-1-8...
#
#                                             OcrText
# 0            As difficult behavior her myself help.
# 1                           Present can phone form.
# 2  Section science difference success wish it wide.
# 3
# 4                    Accept sell leader herself if.

# %%
clean_df = clean_df.groupby(['CaseId'])[['InvalidFileNames', 'ValidFileNames', 'OcrText']].agg(lambda x: ''.join(x.astype(str)))
clean_df.head()
# Out:
#                                                InvalidFileNames  \
# CaseId
# 003061189006
# 003061189067
# 003061189156
# 003061189229  [003061189229_69115288_Master contract_978-0-1...
# 003061189242  [003061189242_91658807_other documents_978-0-7...
#
#                                                  ValidFileNames  \
# CaseId
# 003061189006  [003061189006_69176036_Order form_978-1-62414-...
# 003061189067  [003061189067_26173467_Order form_978-1-904782...
# 003061189156  [003061189156_47966765_Contract Documents_978-...
# 003061189229  [003061189229_21094545_other documents_978-1-8...
# 003061189242
#
#                                                        OcrText
# CaseId
# 003061189006            As difficult behavior her myself help.
# 003061189067                           Present can phone form.
# 003061189156  Section science difference success wish it wide.
# 003061189229                    Accept sell leader herself if.
# 003061189242

# %%
clean_df['InvalidFileNames'] = clean_df['InvalidFileNames'].replace('', '[]')
clean_df['ValidFileNames'] = clean_df['ValidFileNames'].replace('', '[]')
clean_df.head()
# Out:
#                                                InvalidFileNames  \
# CaseId
# 003061189006                                                 []
# 003061189067                                                 []
# 003061189156                                                 []
# 003061189229  [003061189229_69115288_Master contract_978-0-1...
# 003061189242  [003061189242_91658807_other documents_978-0-7...
#
#                                                  ValidFileNames  \
# CaseId
# 003061189006  [003061189006_69176036_Order form_978-1-62414-...
# 003061189067  [003061189067_26173467_Order form_978-1-904782...
# 003061189156  [003061189156_47966765_Contract Documents_978-...
# 003061189229  [003061189229_21094545_other documents_978-1-8...
# 003061189242                                                 []
#
#                                                        OcrText
# CaseId
# 003061189006            As difficult behavior her myself help.
# 003061189067                           Present can phone form.
# 003061189156  Section science difference success wish it wide.
# 003061189229                    Accept sell leader herself if.
# 003061189242

# %%
final_df = pd.merge(clean_df, label, on='CaseId')
final_df.head()
# Out:
#          CaseId                                   InvalidFileNames  \
# 0  003061189006                                                 []
# 1  003061189067                                                 []
# 2  003061189156                                                 []
# 3  003061189229  [003061189229_69115288_Master contract_978-0-1...
# 4  003061189242  [003061189242_91658807_other documents_978-0-7...
#
#                                       ValidFileNames  \
# 0  [003061189006_69176036_Order form_978-1-62414-...
# 1  [003061189067_26173467_Order form_978-1-904782...
# 2  [003061189156_47966765_Contract Documents_978-...
# 3  [003061189229_21094545_other documents_978-1-8...
# 4                                                 []
#
#                                             OcrText label_1 label_2
# 0            As difficult behavior her myself help.    True   False
# 1                           Present can phone form.    True   False
# 2  Section science difference success wish it wide.   False   False
# 3                    Accept sell leader herself if.   False   False
# 4                                                     False   False

# %%
final_df.to_csv("df_final.gzip", index=False, compression="gzip")
